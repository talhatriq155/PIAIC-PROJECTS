# %% [markdown]
# <a href="https://colab.research.google.com/github/talhatriq155/PIAIC-PROJECTS/blob/piaic/double_it.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def double_it():
  current_value=int(input('Enter any number :'))
  while current_value<100:
    current_value=current_value*2
    print(current_value)


double_it()
# Out:
# Enter any number :2
# 4
# 8
# 16
# 32
# 64
# 128
