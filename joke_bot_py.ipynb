# %% [markdown]
# <a href="https://colab.research.google.com/github/talhatriq155/PIAIC-PROJECTS/blob/piaic/joke_bot_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
#   File "<ipython-input-5-56ce6d548012>", line 1
#     pip install google-generativeai SpeechRecognition gtts playsound python-dotenv
#         ^
# SyntaxError: invalid syntax

# %%
# Out:
# WARNING:playsound:playsound is relying on another python subprocess. Please use `pip install pygobject` if you want playsound to run more efficiently.
# Say 'exit' to end the chat.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/speech_recognition/__init__.py in get_pyaudio()
#     102         try:
# --> 103             import pyaudio
#     104         except ImportError:
#
# ModuleNotFoundError: No module named 'pyaudio'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-7637c8dfc56f> in <cell line: 0>()
#      59
#      60 if __name__ == "__main__":
# ---> 61     main()
#
# <ipython-input-3-7637c8dfc56f> in main()
#      46     print("Say 'exit' to end the chat.")
#      47     while True:
# ---> 48         user_input = listen()
#      49         if not user_input:
#      50             continue
#
# <ipython-input-3-7637c8dfc56f> in listen()
#      19 def listen():
#      20     recognizer = sr.Recognizer()
# ---> 21     with sr.Microphone() as source:
#      22         print("Listening...")
#      23         recognizer.adjust_for_ambient_noise(source)
#
# /usr/local/lib/python3.11/dist-packages/speech_recognition/__init__.py in __init__(self, device_index, sample_rate, chunk_size)
#      73
#      74         # set up PyAudio
# ---> 75         self.pyaudio_module = self.get_pyaudio()
#      76         audio = self.pyaudio_module.PyAudio()
#      77         try:
#
# /usr/local/lib/python3.11/dist-packages/speech_recognition/__init__.py in get_pyaudio()
#     103             import pyaudio
#     104         except ImportError:
# --> 105             raise AttributeError("Could not find PyAudio; check installation")
#     106         return pyaudio
#     107
#
# AttributeError: Could not find PyAudio; check installation
