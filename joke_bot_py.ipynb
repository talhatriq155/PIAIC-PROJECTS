# %% [markdown]
# <a href="https://colab.research.google.com/github/talhatriq155/PIAIC-PROJECTS/blob/piaic/joke_bot_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
PROMPT: str = "What do you want? "
JOKE: str = 'My IQ test results came back. They were negative.'
SORRY: str = "Sorry I only tell jokes."

def joke_bot():
    user_input=input("What do you want? :")
    user_input = user_input.strip().lower()

    if user_input=='joke':
        print(JOKE)
    else:
        print(SORRY)


joke_bot()
# Out:
# What do you want? :joke
# My IQ test results came back. They were negative.
